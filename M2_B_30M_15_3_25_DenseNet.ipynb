# %% [markdown]
# # Model One: DenseNet
# This model is trained on binary data: +.25% = buy. -1% = sell.
#
# There are no holds in this dataset. The reason being, we only want to spot when the asset is going to go up or down, which will be implemented with a stop-loss strategy.

# %%
import torch
from torchvision.models import *
from fastai.vision import *

import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
import gc

# %%
# Getting our paths 
images_path = f'{os.curdir}/model_data/images_unscattered'
labels_path = f'{os.curdir}/model_data/unscattered.csv'
path = f'{os.curdir}/model_data'

# %% [markdown]
# ## Unscattered w/ Data Augmentation

# %%
tfms_ = get_transforms(do_flip=False, flip_vert=False, max_rotate=0.0, max_zoom=0.2, max_lighting=0.1, max_warp=0.0)

# Creating source object
seed = np.random.seed(42)
src = (ImageItemList.from_csv(path, csv_name='unscattered.csv', folder='images_unscattered', suffix='.png')
                     .random_split_by_pct(0.1, seed)
                     .label_from_df())

# Creating data object function - returns data object
def get_data(image_size, batch_size):
    data = (src.transform(tfms=tfms_, size=image_size)
               .databunch(num_workers=2, bs=batch_size).normalize(imagenet_stats))
    
    return data

# %%
data = get_data((200,300), 8)
# data = get_data((400, 600), 4)

# %%
data.show_batch()

# %%
gc.collect()
# Out:
# 0

# %%
# Test Architecture
arch = densenet169

# Creating our learner - PRETRAINED on imagenet
learn = create_cnn(data, arch, metrics=[accuracy])
# Out:
# /opt/conda/envs/fastai/lib/python3.6/site-packages/torchvision/models/densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)

# %%
# Finding learning rate
learn.lr_find(num_it=500)
learn.recorder.plot()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
lr = 1e-3

# %%
# Test one
learn.fit_one_cycle(5, slice(lr))
# Out:
# Total time: 11:05 <p><table style='width:300px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>accuracy</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>0.640771</th>
#     <th>0.645957</th>
#     <th>0.686032</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>0.552054</th>
#     <th>0.577449</th>
#     <th>0.713226</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>0.562706</th>
#     <th>0.572262</th>
#     <th>0.734240</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>0.465500</th>
#     <th>0.564222</th>
#     <th>0.721879</th>
#   </tr>
#   <tr>
#     <th>5</th>
#     <th>0.401863</th>
#     <th>0.570521</th>
#     <th>0.730532</th>
#   </tr>
# </table>

# %%
interp = ClassificationInterpretation.from_learner(learn)

# %%
interp.plot_top_losses(20)

# %%
interp.plot_confusion_matrix()

# %%
data
# Out:
# ImageDataBunch;
#
# Train: LabelList
# y: CategoryList (7287 items)
# [Category Sell, Category Sell, Category Sell, Category Sell, Category Buy]...
# Path: model_data
# x: ImageItemList (7287 items)
# [Image (3, 400, 600), Image (3, 400, 600), Image (3, 400, 600), Image (3, 400, 600), Image (3, 400, 600)]...
# Path: model_data;
#
# Valid: LabelList
# y: CategoryList (809 items)
# [Category Buy, Category Sell, Category Buy, Category Sell, Category Sell]...
# Path: model_data
# x: ImageItemList (809 items)
# [Image (3, 400, 600), Image (3, 400, 600), Image (3, 400, 600), Image (3, 400, 600), Image (3, 400, 600)]...
# Path: model_data;
#
# Test: None
